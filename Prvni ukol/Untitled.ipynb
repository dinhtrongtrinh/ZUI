# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
wages_data = np.loadtxt("mzdy.txt")
x = wages_data[:,0]
y = wages_data[:,1]

print(wages_data)
# Out:
# [[ 2000.   11941.  ]
#  [ 2000.25 13227.  ]
#  [ 2000.5  12963.  ]
#  [ 2000.75 14717.  ]
#  [ 2001.   13052.  ]
#  [ 2001.25 14391.  ]
#  [ 2001.5  14117.  ]
#  [ 2001.75 15908.  ]
#  [ 2002.   14083.  ]
#  [ 2002.25 15599.  ]
#  [ 2002.5  15268.  ]
#  [ 2002.75 17133.  ]
#  [ 2003.   14986.  ]
#  [ 2003.25 16529.  ]
#  [ 2003.5  16088.  ]
#  [ 2003.75 18096.  ]
#  [ 2004.   16231.  ]
#  [ 2004.25 17223.  ]
#  [ 2004.5  17190.  ]
#  [ 2004.75 19183.  ]
#  [ 2005.   17067.  ]
#  [ 2005.25 18112.  ]
#  [ 2005.5  18203.  ]
#  [ 2005.75 19963.  ]
#  [ 2006.   18270.  ]
#  [ 2006.25 19300.  ]
#  [ 2006.5  19305.  ]
#  [ 2006.75 21269.  ]
#  [ 2007.   19687.  ]
#  [ 2007.25 20740.  ]
#  [ 2007.5  20721.  ]
#  [ 2007.75 22641.  ]
#  [ 2008.   21647.  ]
#  [ 2008.25 22370.  ]
#  [ 2008.5  22282.  ]
#  [ 2008.75 24484.  ]]

# %%
plt.scatter(x, y, s=10)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Graf")
plt.show()
